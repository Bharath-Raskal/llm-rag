# %% [markdown]
# # LLM RAG Sample Notebook
#
# A starter notebook for experimenting with environment setup and RAG workflows.

# %%
import os
import sys

from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
print("OPENAI_API_KEY loaded:", bool(api_key))
print (sys.executable)
# Out:
# OPENAI_API_KEY loaded: True
# /Users/bharathraskal/Documents/Raskal/Professional/Repo/llm-rag/.venv/bin/python

# %%
import os
import sys

from dotenv import load_dotenv

load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")
print("OPENAI_API_KEY loaded:", bool(api_key))
print (sys.version)
print (sys.executable)
# Out:
# OPENAI_API_KEY loaded: True
# 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# /Users/bharathraskal/Documents/Raskal/Professional/Repo/llm-rag/.venv/bin/python

# %% [markdown]
# ## Next steps
#
# Add document loading, embeddings, and retrieval logic here.
